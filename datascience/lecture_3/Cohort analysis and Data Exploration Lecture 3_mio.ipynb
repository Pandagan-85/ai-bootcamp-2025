# %%
pip install ydata_profiling==4.12.2
# Out:
# Requirement already satisfied: ydata_profiling==4.12.2 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (1.15.2)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (2.2.3)
# Requirement already satisfied: matplotlib>=3.5 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (2.10.6)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (3.1.5)
# Requirement already satisfied: visions<0.8.0,>=0.7.5 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from visions[type_image_path]<0.8.0,>=0.7.5->ydata_profiling==4.12.2) (0.7.6)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (0.14.0)
# Requirement already satisfied: typeguard<5,>=3 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (4.4.2)
# Requirement already satisfied: imagehash==4.3.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from ydata_profiling==4.12.2) (1.9.2)
# Requirement already satisfied: PyWavelets in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from imagehash==4.3.1->ydata_profiling==4.12.2) (1.8.0)
# Requirement already satisfied: pillow in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from imagehash==4.3.1->ydata_profiling==4.12.2) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling==4.12.2) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from matplotlib>=3.5->ydata_profiling==4.12.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from matplotlib>=3.5->ydata_profiling==4.12.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from matplotlib>=3.5->ydata_profiling==4.12.2) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from matplotlib>=3.5->ydata_profiling==4.12.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from matplotlib>=3.5->ydata_profiling==4.12.2) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from matplotlib>=3.5->ydata_profiling==4.12.2) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from matplotlib>=3.5->ydata_profiling==4.12.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling==4.12.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling==4.12.2) (2025.1)
# Requirement already satisfied: joblib>=0.14.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from phik<0.13,>=0.11.1->ydata_profiling==4.12.2) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from pydantic>=2->ydata_profiling==4.12.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from pydantic>=2->ydata_profiling==4.12.2) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from pydantic>=2->ydata_profiling==4.12.2) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata_profiling==4.12.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata_profiling==4.12.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata_profiling==4.12.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from requests<3,>=2.24.0->ydata_profiling==4.12.2) (2025.1.31)
# Requirement already satisfied: patsy>=0.5.2 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from statsmodels<1,>=0.13.2->ydata_profiling==4.12.2) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from visions<0.8.0,>=0.7.5->visions[type_image_path]<0.8.0,>=0.7.5->ydata_profiling==4.12.2) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from visions<0.8.0,>=0.7.5->visions[type_image_path]<0.8.0,>=0.7.5->ydata_profiling==4.12.2) (3.4.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/ds_lecture_1/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->ydata_profiling==4.12.2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
from statsmodels.tsa.seasonal import seasonal_decompose
from ydata_profiling import ProfileReport

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Pandas Profiling

# %% [markdown]
# **Pandas Profiling** è una libreria Python che permette di generare report di analisi esplorativa dei dati in modo rapido e automatico. È progettata per lavorare con i DataFrame di Pandas e fornisce una panoramica completa delle caratteristiche del dataset, tra cui:
#
# **Statistiche descrittive**: medie, deviazioni standard, minimi, massimi, quartili, etc.
#
# **Distribuzioni**: per ogni variabile, viene visualizzata una distribuzione delle frequenze, la presenza di valori mancanti, e la loro distribuzione.
#
# **Correlazion**i: tra variabili numeriche, con un'analisi delle correlazioni statistiche.
#
# **Outlier**: rilevamento di valori anomali o estremi nelle colonne numeriche.
#
# **Distribuzione di dati categorici**: per le variabili non numeriche.
# Il report generato è interattivo e visivamente completo, permettendo di esplorare facilmente il dataset e identificare potenziali problemi come dati mancanti, correlazioni strane, o distribuzioni non uniformi. È particolarmente utile per l'analisi preliminare dei dati.

# %%
df = pd.read_csv("data/titanic.csv")

# %%
profile = ProfileReport(df, title="Report del Dataset", explorative=True)
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-02-21 10:33:22.779268&quot;&gt;&lt;title&gt;Report del Dataset&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# ## Data set Diabets prediction

# %% [markdown]
# Dataset importato da Kaggle
# https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset

# %%
df2 = pd.read_csv("data/diabetes_prediction_dataset.csv")

# %%
df2.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df2.shape
# Out:
# (100000, 9)

# %%
profile2 = ProfileReport(df2, title="Report del Dataset", explorative=True)

# %%
profile2.to_file("report_dataset1.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile2.to_notebook_iframe()
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-02-21 10:33:25.757204&quot;&gt;&lt;title&gt;Report del Dataset&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %%
"""
Funzioni vecchio dataset
from sklearn.preprocessing import LabelEncoder
# Inizializza l'encoder
label_encoder = LabelEncoder()

# Ottieni i valori unici dalla colonna 'Sesso' e applica Label Encoding
df2['Gender_encoded'] = label_encoder.fit_transform(df2['Gender'])
"""
# Out:
# "\nFunzioni vecchio dataset\nfrom sklearn.preprocessing import LabelEncoder\n# Inizializza l'encoder\nlabel_encoder = LabelEncoder()\n\n# Ottieni i valori unici dalla colonna 'Sesso' e applica Label Encoding\ndf2['Gender_encoded'] = label_encoder.fit_transform(df2['Gender'])\n"

# %%
df2.head(10)
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
# 5  Female  20.0             0              0           never  27.32
# 6  Female  44.0             0              0           never  19.31
# 7  Female  79.0             0              0         No Info  23.86
# 8    Male  42.0             0              0           never  33.64
# 9  Female  32.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0
# 5          6.6                   85         0
# 6          6.5                  200         1
# 7          5.7                   85         0
# 8          4.8                  145         0
# 9          5.0                  100         0

# %%
df2.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
# Diabetes Diagnosis

# %%
# Glucose_Level, Age, HbA1c, BMI, Insulin_Resistance, Physical_Activity_Level, Family_History_Diabetes

# %%
# converto la classe gender in numerico
from sklearn.preprocessing import LabelEncoder
# Inizializza l'encoder
label_encoder = LabelEncoder()

# Ottieni i valori unici dalla colonna 'Sesso' e applica Label Encoding
df2['Gender_encoded'] = label_encoder.fit_transform(df2['gender'])

# %%
df2['gender'].unique
# Out:
# <bound method Series.unique of 0        Female
# 1        Female
# 2          Male
# 3        Female
# 4          Male
#           ...
# 99995    Female
# 99996    Female
# 99997      Male
# 99998    Female
# 99999    Female
# Name: gender, Length: 100000, dtype: object>

# %%
df2.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes  Gender_encoded
# 0          6.6                  140         0               0
# 1          6.6                   80         0               0
# 2          5.7                  158         0               1
# 3          5.0                  155         0               0
# 4          4.8                  155         0               1

# %%
g = sns.FacetGrid(df2, col="Gender_encoded")
g.map(sns.histplot, "diabetes", bins = 20, color="teal")
plt.tight_layout()

plt.show()

# %%
df2['age'].describe()
# Out:
# count    100000.000000
# mean         41.885856
# std          22.516840
# min           0.080000
# 25%          24.000000
# 50%          43.000000
# 75%          60.000000
# max          80.000000
# Name: age, dtype: float64

# %%
df2['age_level'] = df2['age'].apply(lambda x: 'young' if x < 25 else 'adult' if x < 55 else 'old')

# %%
df2['age_gender'] = df2['age_level'] + "_" + df2['gender']

# %%
g = sns.FacetGrid(df2, col="age_gender",height=5, aspect=1.5, col_wrap=3)
g.map(sns.histplot, "diabetes", bins = 20, color="teal")
plt.tight_layout()

plt.show()

# %%
numeric_db = df2.select_dtypes(include = ['int64', 'float64'])

correlation = numeric_db.corr()['diabetes'].sort_values(ascending = False)


plt.figure(figsize = (10,8))
top_features = correlation[1:]
sns.barplot(x = top_features.values, y = top_features.index)
plt.title('Top 10 Features Correlated with Diabetes_Diagnosis')
plt.xlabel('Correlation Coefficient')
plt.tight_layout()
plt.show()

correlation.apply(lambda x: f"{x:.3f} ({'Strong' if abs(x) > 0.5 else 'Moderate' if abs(x) > 0.03 else 'Weak'})").head(10)
# Out:
# diabetes                 1.000 (Strong)
# blood_glucose_level    0.420 (Moderate)
# HbA1c_level            0.401 (Moderate)
# age                    0.258 (Moderate)
# bmi                    0.214 (Moderate)
# hypertension           0.198 (Moderate)
# heart_disease          0.172 (Moderate)
# Gender_encoded         0.037 (Moderate)
# Name: diabetes, dtype: object

# %%
# %% [code]
# Box Plot: HbA1c_level levels by gende

x = "age_gender"
y = "HbA1c_level"
sns.boxplot(x=x, y=y, data=df2)
plt.title(f"{y} Levels by {x}")
plt.show()

# %%
x = "age_gender"
y = "blood_glucose_level"
sns.boxplot(x=x, y=y, data=df2)
plt.title(f"{y} Levels by {x}")
plt.tight_layout()

plt.show()

# %%
# %% [code]
# Violin Plot: Glucose Level by Smoking Status

x = "hypertension"
y = "blood_glucose_level"

sns.violinplot(x=x, y=y, data=df2)
plt.title(f"{y} by {x}")
plt.show()

# %%
x = "heart_disease"
y = "blood_glucose_level"
sns.violinplot(x=x, y=y, data=df2)
plt.title(f"{y} Levels by {x}")
plt.show()

# %%
sns.pairplot(df2[['diabetes', 'age', 'blood_glucose_level', 'bmi']], diag_kind='kde')
plt.show()

# %%
# %% [code]
# KDE Plot for BMI Distribution using Seaborn
x = "HbA1c_level"
sns.kdeplot(data=df2, x=x, fill=True, color='green', clip=(min(df2[x]), max(df2[x])))
plt.title("HbA1c_level Density Plot")
plt.show()

# %% [markdown]
# # Tips
# è utile dividere in classi le variabili numeriche, rivedere dal suo notebook.
# **creare classi impattanti per poter prevedere il nostro target**

# %%
df2['bglc'] = df2['blood_glucose_level'].apply(lambda x : "high" if x > 200 else "low")

# %%
df2[df2['bglc'] =="high"].shape[0]/df2.shape[0]
# Out:
# 0.03277

# %%
df2["sh_ht"] = df2["smoking_history"] + df2["hypertension"].astype(str)

# %%
df2["sh_ht"].head()
# Out:
# 0      never0
# 1    No Info0
# 2      never0
# 3    current0
# 4    current1
# Name: sh_ht, dtype: object

# %%
g = sns.FacetGrid(df2, col="sh_ht",height=5, aspect=1.5, col_wrap=2)
g.map(sns.histplot, "diabetes", bins = 20, color="teal")
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Costruiamo la classe che secondo noi è quella più probabile che abbia il diabete

# %%
df2["gender_class"] = df2["age"].apply(lambda x: "old" if x > 55 else "other")

df2["ht_class"] = "H"+ df2["hypertension"].astype(str)

df2["HbA1c_class"] = df2["HbA1c_level"].apply(lambda x: "high" if x > 5.5 else "other")

df2["final_class"] = df2["gender_class"] + '_' + df2["ht_class"]  + '_' + df2["HbA1c_class"]

# %%
g = sns.FacetGrid(df2, col="final_class",height=5, aspect=1.5, col_wrap=2)
g.map(sns.histplot, "diabetes", bins = 20, color="teal")
plt.tight_layout()

plt.show()
