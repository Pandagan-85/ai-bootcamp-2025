# %% [markdown]
# ## Creare un dataframe da un dict

# %%
import pandas as pd

data = {
    "Name": ['Alice', 'Bob', 'Charlie'],
    "Age": [25,30,35],
    "City": ["New York", "Los Angelse", "Chicago"]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angelse
# 2  Charlie   35      Chicago

# %%
oldest = df["Age"]

# %%
oldest
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
oldest.idxmax()
# Out:
# 2

# %%
oldest.idxmin()
# Out:
# 0

# %%
oldest_idx = df["Age"].idxmax()

# %%
oldest_record = df.loc[oldest_idx]
oldest_record
# Out:
# Name    Charlie
# Age          35
# City    Chicago
# Name: 2, dtype: object

# %%
## Creare un dataframe da un lista
data2 = [
    ["Alice", 25, "New York"],
    ["Bob", 30, "Los Angeles"],
    ["Charlie", 35, "Chicago"],
]

df2 = pd.DataFrame(data2, columns=['Name', 'Age', 'City'])
df2
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %% [markdown]
# # API

# %% [markdown]
# ## Importare da file json con richiesta GET

# %% [markdown]
# Io in next/javascprit usavo:
# ```
# fetch('https://api.example.com/data', {
#     method: 'GET',
#     headers: {
#       'Content-Type': 'application/json',
#       'Authorization': 'Bearer <token>',
#       'Accept': 'application/json',
#       'Custom-Header': 'value'
#     }
#   })
#   .then(response => response.json())
#   .then(data => console.log(data))
#   .catch(error => console.error('Error:', error));
# ```

# %% [markdown]
# Invece in Python usiamo la libreria `requests` che fa praticamente lo stesso:

# %%
import requests

url = "https://opendata.ecdc.europa.eu/covid19/casedistribution/json/"

response = requests.get(url)

data = response.json()

df3 = pd.DataFrame(data['records'])

# %%
df3.head()
# Out:
#       dateRep day month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020  14    12  2020    746       6             Afghanistan    AF
# 1  13/12/2020  13    12  2020    298       9             Afghanistan    AF
# 2  12/12/2020  12    12  2020    113      11             Afghanistan    AF
# 3  11/12/2020  11    12  2020     63      10             Afghanistan    AF
# 4  10/12/2020  10    12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#   Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                         9.01377925
# 1                                         7.05277624
# 2                                         6.86876792
# 3                                         7.13426564
# 4                                         6.96865815

# %% [markdown]
# ## Web scraping
# Il **web scraping** è una tecnica utilizzata per estrarre dati da siti web. Si tratta di un processo automatizzato che raccoglie informazioni da una pagina web e le converte in un formato utile (come un file CSV, un database, o un altro formato strutturato).

# %% [markdown]
# ### BeautifulSoup
# è una libreria Python molto utilizzata per parsing HTML e XML, che permette di estrarre dati da pagine web in modo semplice e strutturato. È particolarmente utile nel contesto del web scraping, dove si desidera ottenere informazioni da siti web. La libreria è chiamata così per la sua capacità di rendere il codice HTML “spigoloso” più facile da leggere e manipolare.

# %% [markdown]
# ## Esercizio Scraping book

# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://books.toscrape.com/"

response = requests.get(base_url)

soup = BeautifulSoup(response.text)

links = soup.find_all("a")

link = links[0]

# print(links)

print([repr(obj) for obj in links])
# Out:
# ['<a href="index.html">Books to Scrape</a>', '<a href="index.html">Home</a>', '<a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>', '<a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>', '<a href="catalogue/category/books/mystery_3/index.html">\n                            \n                                Mystery\n                            \n                        </a>', '<a href="catalogue/category/books/historical-fiction_4/index.html">\n                            \n                                Historical Fiction\n                            \n                        </a>', '<a href="catalogue/category/books/sequential-art_5/index.html">\n                            \n                                Sequential Art\n                            \n                        </a>', '<a href="catalogue/category/books/classics_6/index.html">\n                            \n                                Classics\n                            \n                        </a>', '<a href="catalogue/category/books/philosophy_7/index.html">\n                            \n                                Philosophy\n                            \n                        </a>', '<a href="catalogue/category/books/romance_8/index.html">\n                            \n                                Romance\n                            \n                        </a>', '<a href="catalogue/category/books/womens-fiction_9/index.html">\n                            \n                                Womens Fiction\n                            \n                        </a>', '<a href="catalogue/category/books/fiction_10/index.html">\n                            \n                                Fiction\n                            \n                        </a>', '<a href="catalogue/category/books/childrens_11/index.html">\n                            \n                                Childrens\n                            \n                        </a>', '<a href="catalogue/category/books/religion_12/index.html">\n                            \n                                Religion\n                            \n                        </a>', '<a href="catalogue/category/books/nonfiction_13/index.html">\n                            \n                                Nonfiction\n                            \n                        </a>', '<a href="catalogue/category/books/music_14/index.html">\n                            \n                                Music\n                            \n                        </a>', '<a href="catalogue/category/books/default_15/index.html">\n                            \n                                Default\n                            \n                        </a>', '<a href="catalogue/category/books/science-fiction_16/index.html">\n                            \n                                Science Fiction\n                            \n                        </a>', '<a href="catalogue/category/books/sports-and-games_17/index.html">\n                            \n                                Sports and Games\n                            \n                        </a>', '<a href="catalogue/category/books/add-a-comment_18/index.html">\n                            \n                                Add a comment\n                            \n                        </a>', '<a href="catalogue/category/books/fantasy_19/index.html">\n                            \n                                Fantasy\n                            \n                        </a>', '<a href="catalogue/category/books/new-adult_20/index.html">\n                            \n                                New Adult\n                            \n                   ...

# %%
import requests
from bs4 import BeautifulSoup

# URL della pagina principale
url = 'https://books.toscrape.com/'

# Effettua una richiesta GET per ottenere il contenuto HTML della pagina
response = requests.get(url)

# Usa BeautifulSoup per fare il parsing del contenuto HTML
soup = BeautifulSoup(response.text, 'html.parser')

# Trova tutti i libri nella lista
books = soup.find('ol', class_='row').find_all('li')

# Estrai informazioni sui libri
for book in books:
    title = book.find('h3').find('a')['title']
    price = book.find('p', class_='price_color').text
    link = book.find('h3').find('a')['href']
    
    print(f'Title: {title}, Price: {price}, Link: {link}')
# Out:
# Title: A Light in the Attic, Price: Â£51.77, Link: catalogue/a-light-in-the-attic_1000/index.html
# Title: Tipping the Velvet, Price: Â£53.74, Link: catalogue/tipping-the-velvet_999/index.html
# Title: Soumission, Price: Â£50.10, Link: catalogue/soumission_998/index.html
# Title: Sharp Objects, Price: Â£47.82, Link: catalogue/sharp-objects_997/index.html
# Title: Sapiens: A Brief History of Humankind, Price: Â£54.23, Link: catalogue/sapiens-a-brief-history-of-humankind_996/index.html
# Title: The Requiem Red, Price: Â£22.65, Link: catalogue/the-requiem-red_995/index.html
# Title: The Dirty Little Secrets of Getting Your Dream Job, Price: Â£33.34, Link: catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html
# Title: The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull, Price: Â£17.93, Link: catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html
# Title: The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics, Price: Â£22.60, Link: catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html
# Title: The Black Maria, Price: Â£52.15, Link: catalogue/the-black-maria_991/index.html
# Title: Starving Hearts (Triangular Trade Trilogy, #1), Price: Â£13.99, Link: catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html
# Title: Shakespeare's Sonnets, Price: Â£20.66, Link: catalogue/shakespeares-sonnets_989/index.html
# Title: Set Me Free, Price: Â£17.46, Link: catalogue/set-me-free_988/index.html
# Title: Scott Pilgrim's Precious Little Life (Scott Pilgrim #1), Price: Â£52.29, Link: catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html
# Title: Rip it Up and Start Again, Price: Â£35.02, Link: catalogue/rip-it-up-and-start-again_986/index.html
# Title: Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991, Price: Â£57.25, Link: catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html
# Title: Olio, Price: Â£23.88, Link: catalogue/olio_984/index.html
# Title: Mesaerion: The Best Science Fiction Stories 1800-1849, Price: Â£37.59, Link: catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html
# Title: Libertarianism for Beginners, Price: Â£51.33, Link: catalogue/libertarianism-for-beginners_982/index.html
# Title: It's Only the Himalayas, Price: Â£45.17, Link: catalogue/its-only-the-himalayas_981/index.html

# %% [markdown]
# # Scraping e creazione del dizionario per i primi 20 libri
# Mia soluzione usando le classi per prendere la sezione in cui vengono mostrati i libri, e sfruttando la paginazione tipica degli e-commerce.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re  # Importa il modulo per le espressioni regolari per estrarre i numeri da una stringa

# Lista per raccogliere i dati dei libri
book_data = []

# Funzione per ottenere i dettagli da una singola pagina del libro
def get_book_details(book_url):
    """
    Viene inviata una richiesta HTTP per ottenere la pagina del libro.
    Si effettua il parsing del contenuto HTML per trovare la tabella che contiene i dettagli del libro.
    Viene creata una lista di informazioni del libro (come disponibilità, prezzo, numero di recensioni)
    ed è presente una gestione speciale per l'Availability, per estrarre solo il numero di copie disponibili.
    ed elimino il simbolo della currency dalle tre colonne di prezzo (iva, no iva, tax)
    """
    # Invia una richiesta HTTP per ottenere il contenuto della pagina
    response = requests.get(book_url)
    response.encoding = 'utf-8'  # Forza la corretta decodifica del contenuto (UTF-8)
    # Parso la risposta HTML con BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Cerca la tabella con la classe 'table table-striped', che contiene i dettagli del libro
    table = soup.find('table', class_='table table-striped')
    
    # Se la tabella è stata trovata, estrai le informazioni
    if table:
        print(f"Table found in {book_url}")
        # Trova tutte le righe della tabella
        rows = table.find_all('tr')
        
        # Dizionario per memorizzare le informazioni del libro
        book_info = {}
        
        # Per ogni riga della tabella, estrai il nome della proprietà (th) e il valore (td)
        for row in rows:
            header = row.find('th')
            value = row.find('td')
            
            # Se sia la proprietà che il valore esistono, aggiungi l'informazione al dizionario
            if header and value:
                property_name = header.text.strip()  # Nome della proprietà (senza spazi)
                property_value = value.text.strip()  # Valore della proprietà (senza spazi)

               # Lista delle proprietà che richiedono l'estrazione del numero (senza decimali)
                properties_to_extract = ["Availability"]

                # Lista delle proprietà che devono mantenere i decimali (come prezzo e tasse)
                properties_with_decimals = ["Price (excl. tax)", "Price (incl. tax)", "Tax"]

                # Se la proprietà è una delle proprietà che richiedono solo il numero intero
                if property_name in properties_to_extract:
                    match = re.search(r'\d+', property_value)  # Trova il numero nell'informazione
                    property_value = match.group() if match else '0'  # Se trovato, usa il numero; altrimenti usa '0'

                # Se la proprietà è una delle proprietà con decimali (prezzo o tassa), mantieni i decimali
                elif property_name in properties_with_decimals:
                    match = re.search(r'[\d.,]+', property_value)  # Trova il numero con decimali (gestisce virgola o punto)
                    property_value = match.group() if match else '0.0'  # Se trovato, usa il numero; altrimenti usa '0.0
                               
                # Aggiungi la coppia proprietà-valore al dizionario
                book_info[property_name] = property_value
        
        # Restituisci i dettagli del libro sotto forma di dizionario
        return book_info
    else:
        print(f"No table found in {book_url}")  # Se non trova la tabella, segnala un errore
        return None

# Funzione per ottenere i libri dalla pagina principale
def get_books(url):
    """
    Viene inviata una richiesta per ottenere il contenuto della pagina principale con tutti i libri.
    Si trova ogni libro nell'elenco e si estrae il titolo, il prezzo e il link alla pagina del libro.
    Per ogni libro, viene chiamata la funzione get_book_details() per ottenere i dettagli completi.
    """
    # Invia una richiesta HTTP per ottenere il contenuto della pagina
    response = requests.get(url)
    response.encoding = 'utf-8'  # Forza la corretta decodifica del contenuto
    # Parso la risposta HTML con BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Trova l'elenco dei libri sulla pagina (tutti i libri sono in un <ol class='row'>)
    books = soup.find('ol', class_='row').find_all('li')

    # Per ogni libro trovato nell'elenco
    for book in books:
        # Estrai il titolo del libro
        title = book.find('h3').find('a')['title']
        # Estrai il prezzo del libro
        price = book.find('p', class_='price_color').text.strip()
        
        price_cleaned = price.replace('£', '').strip()  # Rimuove '£' e gli spazi extra


        
        # Estrai il link alla pagina del libro
        link = book.find('h3').find('a')['href']
        
        # Costruisci il link completo del libro (aggiungendo il prefisso necessario)
        book_url = 'https://books.toscrape.com/catalogue/' + link.strip('../')
        
        # Chiama la funzione get_book_details per ottenere i dettagli del libro
        book_details = get_book_details(book_url)
        
        # Se i dettagli del libro sono stati trovati
        if book_details:
            # Aggiungi il titolo, il prezzo e il link ai dettagli
            book_details['Title'] = title
            book_details['Price'] = price_cleaned
            book_details['Link'] = book_url

            # Aggiungi i dettagli del libro alla lista book_data
            book_data.append(book_details)

# URL della prima pagina di libri (paginata)
base_url = 'https://books.toscrape.com/catalogue/page-'

# Inizia con la prima pagina
page_num = 1
book_counter = 0

# Ciclo per raccogliere i dati dei primi 10 libri
while book_counter < 10:
    # Costruisci l'URL della pagina corrente
    url = f'{base_url}{page_num}.html'
    # Invia una richiesta HTTP per ottenere il contenuto della pagina
    response = requests.get(url)
    
    # Se la risposta non è valida (errore 404 o simili), esci dal ciclo
    if response.status_code != 200:
        break

    print(f'Getting books from: {url}')
    
    # Chiama la funzione get_books per estrarre i dati dalla pagina
    get_books(url)
    
    # Aumenta il contatore dei libri, considerando che ogni pagina contiene 20 libri
    book_counter += 20  

    # Ferma dopo aver ottenuto i primi 10 libri
    if book_counter >= 10:
        break

    # Passa alla pagina successiva
    page_num += 1

# Creazione del DataFrame a partire dai dati raccolti
df_mio = pd.DataFrame(book_data)

# Modifica il tipo della colonna 'Link' a stringa, se necessario
df_mio['Link'] = df_mio['Link'].astype(str)

# Salva il DataFrame in un file CSV
df_mio.to_csv('books_data.csv', index=False, encoding='utf-8')
# Out:
# Getting books from: https://books.toscrape.com/catalogue/page-1.html
# Table found in https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html
# Table found in https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html
# Table found in https://books.toscrape.com/catalogue/soumission_998/index.html
# Table found in https://books.toscrape.com/catalogue/sharp-objects_997/index.html
# Table found in https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html
# Table found in https://books.toscrape.com/catalogue/the-requiem-red_995/index.html
# Table found in https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html
# Table found in https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html
# Table found in https://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html
# Table found in https://books.toscrape.com/catalogue/the-black-maria_991/index.html
# Table found in https://books.toscrape.com/catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html
# Table found in https://books.toscrape.com/catalogue/shakespeares-sonnets_989/index.html
# Table found in https://books.toscrape.com/catalogue/set-me-free_988/index.html
# Table found in https://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html
# Table found in https://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html
# Table found in https://books.toscrape.com/catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html
# Table found in https://books.toscrape.com/catalogue/olio_984/index.html
# Table found in https://books.toscrape.com/catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html
# Table found in https://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html
# Table found in https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html

# %%
df_mio.columns
# Out:
# Index(['UPC', 'Product Type', 'Price (excl. tax)', 'Price (incl. tax)', 'Tax',
#        'Availability', 'Number of reviews', 'Title', 'Price', 'Link'],
#       dtype='object')

# %%
pd.set_option('display.max_colwidth', None)
df_mio
# Out:
#                  UPC Product Type Price (excl. tax) Price (incl. tax)   Tax  \
# 0   a897fe39b1053632        Books             51.77             51.77  0.00
# 1   90fa61229261140a        Books             53.74             53.74  0.00
# 2   6957f44c3847a760        Books             50.10             50.10  0.00
# 3   e00eb4fd7b871a48        Books             47.82             47.82  0.00
# 4   4165285e1663650f        Books             54.23             54.23  0.00
# 5   f77dbf2323deb740        Books             22.65             22.65  0.00
# 6   2597b5a345f45e1b        Books             33.34             33.34  0.00
# 7   e72a5dfc7e9267b2        Books             17.93             17.93  0.00
# 8   e10e1e165dc8be4a        Books             22.60             22.60  0.00
# 9   1dfe412b8ac00530        Books             52.15             52.15  0.00
# 10  0312262ecafa5a40        Books             13.99             13.99  0.00
# 11  30a7f60cd76ca58c        Books             20.66             20.66  0.00
# 12  ce6396b0f23f6ecc        Books             17.46             17.46  0.00
# 13  3b1c02bac2a429e6        Books             52.29             52.29  0.00
# 14  a34ba96d4081e6a4        Books             35.02             35.02  0.00
# 15  deda3e61b9514b83        Books             57.25             57.25  0.00
# 16  feb7cc7701ecf901        Books             23.88             23.88  0.00
# 17  e30f54cea9b38190        Books             37.59             37.59  0.00
# 18  a18a4f574854aced        Books             51.33             51.33  0.00
# 19  a22124811bfa8350        Books             45.17             45.17  0.00
#
#    Availability Number of reviews  \
# 0            22                 0
# 1            20                 0
# 2            20                 0
# 3            20                 0
# 4            20                 0
# 5            19                 0
# 6            19                 0
# 7            19                 0
# 8            19                 0
# 9            19                 0
# 10           19                 0
# 11           19                 0
# 12           19                 0
# 13           19                 0
# 14           19                 0
# 15           19                 0
# 16           19                 0
# 17           19                 0
# 18           19                 0
# 19           19                 0
#
#                                                                                              Title  \
# 0                                                                             A Light in the Attic
# 1                                                                               Tipping the Velvet
# 2                                                                                       Soumission
# 3                                                                                    Sharp Objects
# 4                                                            Sapiens: A Brief History of Humankind
# 5                                                                                  The Requiem Red
# 6                                               The Dirty Little Secrets of Getting Your Dream Job
# 7          The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# 8   The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# 9                                                                                  The Black Maria
# 10                                                  Starving Hearts (Triangular Trade Trilogy, #1)
# 11                                                                           Shakespeare's Sonnets
# 12                                                                                     Set Me Free
# 13                                         Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# 14                                                                       Rip it Up and Start Again
# 15              Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# 16                                                                                            Olio
# 17                                           Mesaerion: The Best Science Fiction Stories 1800-1849
# 18                                                                    Libertarianism for Beginners
# 19                                                                         It's Only the Himalayas
#
#     Price  \
# 0   51.77
# 1   53.74
# 2   50.10
# 3   47.82
# 4   54.23
# 5   22.65
# 6   33.34
# 7   17.93
# 8   22.60
# 9   52.15
# 10  13.99
# 11  20.66
# 12  17.46
# 13  52.29
# 14  35.02
# 15  57.25
# 16  23.88
# 17  37.59
# 18  51.33
# 19  45.17
#
#                                                                                                                                                  Link
# 0                                                                           https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html
# 1                                                                              https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html
# 2                                                                                      https://books.toscrape.com/catalogue/soumission_998/index.html
# 3                                                                                   https://books.toscrape.com/catalogue/sharp-objects_997/index.html
# 4                                                            https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html
# 5                                                                                 https://books.toscrape.com/catalogue/the-requiem-red_995/index.html
# 6                                              https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html
# 7           https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html
# 8   https://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html
# 9                                                                                 https://books.toscrape.com/catalogue/the-black-maria_991/index.html
# 10                                                     https://books.toscrape.com/catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html
# 11                                                                           https://books.toscrape.com/catalogue/shakespeares-sonnets_989/index.html
# 12                                                                                    https://books.toscrape.com/catalogue/set-me-free_988/index.html
# 13                                            https://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html
# 14                                                                      https://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html
# 15               https://books.toscrape.com/catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html
# 16                                                                                           https://books.toscrape.com/catalogue/olio_984/index.html
# 17                                           https://books.toscrape.com/catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html
# 18                                                                   https://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html
# 19                                                                         https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html

# %% [markdown]
# # Scraping Soluzione Rigel! 🚀
# è mooooolto più dinamica, non ha limiti di pagine e scansiona tuttooooo, escludendo anche i link già visitati.

# %%
import sys
import time
import json
from pathlib import Path

import pandas as pd
import requests
from bs4 import BeautifulSoup

# Creo un set: https://docs.python.org/3/tutorial/datastructures.html#sets
# Questo mi permette di aggiungere in tempo O1 (nei casi pratici)
# e verificare la presenza di una chiave sempre in tempo 01.
# Posso fare lo stesso usando i dict, mentre le liste sono
# molto meno efficienti (On per la verifica)
ignored = {
    "index.html",
    "https://books.toscrape.com/index.html",
}

# L'URL da cui partire
base_url = "https://books.toscrape.com/"

financial_keys = (
    'Price (excl. tax)',
    'Price (incl. tax)',
    'Tax'
)
numerical_keys = (
    "Number of reviews",
)

data = []


def get_parent_url(url):
    """Get the parent of the given URL
    e.g. https://www.example.com/abc/cde.html -> https://www.example.com/abc/
    """
    *parent_parts, _ = url.split("/")
    return "/".join(parent_parts)


def rows_to_dict(rows):
    """Convert a sequence of rows of an HTML table to a dict"""
    rows_data = {el.th.text: el.td.text for el in rows}
    for key, val in rows_data.items():
        if key in financial_keys:
            # Correggi il dato e lo trasformo in decimale
            # 'Â£51.77' -> 51.77
            # Per farlo escludo i primi due caratteri
            rows_data[key] = float(val[2:])
        if key in numerical_keys:
            # Converti il dato in un numero intero
            rows_data[key] = int(val)
    return rows_data

def crawl(url):
    """Crawl the page at the given URL
    Any tables will be added as dicts to the
    module-level name "data".
    Perform the crawl using the breadth-first
    algorithm (BFS).
    """

    # Prendo la URL base
    parent_url = get_parent_url(url)

    # Invio una chiamata GET usando l'URL
    response = requests.get(url)

    status_code = response.status_code
    if status_code != 200:
        raise Exception(f"Il server ha risposto con uno status code inaspettato: {status_code}")

    # Faccio il parsing del HTML della pagina
    soup = BeautifulSoup(response.text, features="html.parser")

    # Cerco tutti gli element tr (table row) nella pagina (se ci sono)
    rows = soup.find_all("tr")

    # Se li trovo, li converto in un dict e li aggiungo ai dati
    row_data = rows_to_dict(rows)
    if row_data:
        data.append(row_data)
        # Aspetto un secondo prima di proseguire
        # in modo da non caricare troppo il server
        time.sleep(1)

    # Ora cerco tutti i link all'interno della prima sezione della pagina
    links = soup.find_all("section")[0].find_all("a")
    print(f"Crawled: {url} and found {len(links)} new links and {len(rows)} table rows.", file=sys.stderr)
    for link in links:
        # Prendo il link (nell'attributo HREF)
        link_rel = link.attrs["href"]

        # Ignora i link che tornano indietro
        if ".." in link_rel:
            continue

        # Se non è un link assoluto (che comincia con "http")...
        if not link_rel.startswith("http"):
            # ... lo rendo assoluto usando la URL base
            url = "/".join([parent_url, link_rel])
        else:
            url = link_rel

        # I link esterni vanno ignorati
        if not url.startswith(base_url):
            continue

        # Se ho già incontrato il link, lo ignoro
        if url in ignored:
            continue

        # Aggiungo la URL alla lista da ignorare
        ignored.add(url)

        # Chiamata ricorsiva
        crawl(url)


# Faccio partire il crawl
try:
    crawl(base_url)
except KeyboardInterrupt:
    pass

# Creo e stampo il dataframe
df = pd.DataFrame(data)
print(df)

# Salvo i dati JSON in un file per poterli utilizzare dopo
with open("books.json", "w") as fd:
    fd.write(json.dumps(data))
# Out:
# Crawled: https://books.toscrape.com/ and found 41 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/soumission_998/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/sharp-objects_997/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-requiem-red_995/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-black-maria_991/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/shakespeares-sonnets_989/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/set-me-free_988/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/olio_984/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-2.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/in-her-wake_980/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/how-music-works_979/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/chase-me-paris-nights-2_977/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/black-dust_976/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/birdsong-a-story-in-pictures_975/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/americas-cradle-of-quarterbacks-western-pennsylvanias-football-factory-from-johnny-unitas-to-joe-montana_974/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/aladdin-and-his-wonderful-lamp_973/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/worlds-elsewhere-journeys-around-shakespeares-globe_972/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/wall-and-piece_971/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-four-agreements-a-practical-guide-to-personal-freedom_970/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-five-love-languages-how-to-express-heartfelt-commitment-to-your-mate_969/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-elephant-tree_968/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-bear-and-the-piano_967/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/sophies-world_966/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/penny-maybe_965/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/maude-1883-1993she-grew-up-with-the-country_964/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/in-a-dark-dark-wood_963/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/behind-closed-doors_962/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/you-cant-bury-them-all-poems_961/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-1.html and found 41 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-3.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/reasons-to-stay-alive_959/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/private-paris-private-10_958/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/higherselfie-wake-up-your-life-free-your-soul-find-your-tribe_957/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/without-borders-wanderlove-1_956/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/when-we-collided_955/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/we-love-you-charlie-freeman_954/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/untitled-collection-sabbath-poems-2014_953/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/unseen-city-the-majesty-of-pigeons-the-discreet-charm-of-snails-other-wonders-of-the-urban-wilderness_952/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/unicorn-tracks_951/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/unbound-how-eight-technologies-made-us-human-transformed-society-and-brought-our-world-to-the-brink_950/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/tsubasa-world-chronicle-2-tsubasa-world-chronicle-2_949/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/throwing-rocks-at-the-google-bus-how-growth-became-the-enemy-of-prosperity_948/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/this-one-summer_947/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/thirst_946/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-torch-is-passed-a-harding-family-story_945/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-secret-of-dreadwillow-carse_944/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-pioneer-woman-cooks-dinnertime-comfort-classics-freezer-food-16-minute-meals-and-other-delicious-ways-to-solve-supper_943/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-past-never-ends_942/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-natural-history-of-us-the-fine-art-of-pretending-2_941/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-4.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-murder-that-never-was-forensic-instincts-5_939/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-most-perfect-thing-inside-and-outside-a-birds-egg_938/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-mindfulness-and-acceptance-workbook-for-anxiety-a-guide-to-breaking-free-from-anxiety-phobias-and-worry-using-acceptance-and-commitment-therapy_937/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-life-changing-magic-of-tidying-up-the-japanese-art-of-decluttering-and-organizing_936/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-inefficiency-assassin-time-management-tactics-for-working-smarter-not-longer_935/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-gutsy-girl-escapades-for-your-life-of-epic-adventure_934/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-electric-pencil-drawings-from-inside-state-hospital-no-3_933/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-death-of-humanity-and-the-case-for-life_932/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-bulletproof-diet-lose-up-to-a-pound-a-day-reclaim-energy-and-focus-upgrade-your-life_931/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-art-forger_930/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-age-of-genius-the-seventeenth-century-and-the-birth-of-the-modern-mind_929/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-activists-tao-te-ching-ancient-advice-for-a-modern-revolution_928/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/spark-joy-an-illustrated-master-class-on-the-art-of-organizing-and-tidying-up_927/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/soul-reader_926/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/security_925/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/saga-volume-6-saga-collected-editions-6_924/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/saga-volume-5-saga-collected-editions-5_923/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/reskilling-america-learning-to-labor-in-the-twenty-first-century_922/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/rat-queens-vol-3-demons-rat-queens-collected-editions-11-15_921/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-5.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/princess-between-worlds-wide-awake-princess-5_919/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/pop-gun-war-volume-1-gift_918/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/political-suicide-missteps-peccadilloes-bad-calls-backroom-hijinx-sordid-pasts-rotten-breaks-and-just-plain-dumb-mistakes-in-the-annals-of-american-politics_917/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/patience_916/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/outcast-vol-1-a-darkness-surrounds-him-outcast-1_915/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/orange-the-complete-collection-1-orange-the-complete-collection-1_914/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/online-marketing-for-busy-authors-a-step-by-step-guide_913/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/on-a-midnight-clear_912/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/obsidian-lux-1_911/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/my-paris-kitchen-recipes-and-stories_910/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/masks-and-shadows_909/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/mama-tried-traditional-italian-cooking-for-the-screwed-crude-vegan-and-tattooed_908/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/lumberjanes-vol-2-friendship-to-the-max-lumberjanes-5-8_907/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/lumberjanes-vol-1-beware-the-kitten-holy-lumberjanes-1-4_906/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/lumberjanes-vol-3-a-terrible-plan-lumberjanes-9-12_905/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/layered-baking-building-and-styling-spectacular-cakes_904/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/judo-seven-steps-to-black-belt-an-introductory-guide-for-beginners_903/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/join_902/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/in-the-country-we-love-my-family-divided_901/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-6.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/i-hate-fairyland-vol-1-madly-ever-after-i-hate-fairyland-compilations-1-5_899/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/i-am-a-hero-omnibus-volume-1_898/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/how-to-be-miserable-40-strategies-you-already-use_897/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/her-backup-boyfriend-the-sorensen-family-1_896/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/giant-days-vol-2-giant-days-5-8_895/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/forever-and-forever-the-courtship-of-henry-longfellow-and-fanny-appleton_894/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/first-and-first-five-boroughs-3_893/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/fifty-shades-darker-fifty-shades-2_892/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/everydata-the-misinformation-hidden-in-the-little-data-you-consume-every-day_891/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/dont-be-a-jerk-and-other-practical-advice-from-dogen-japans-greatest-zen-master_890/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/danganronpa-volume-1_889/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/crown-of-midnight-throne-of-glass-2_888/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/codename-baboushka-volume-1-the-conclave-of-death_887/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/camp-midnight_886/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/call-the-nurse-true-stories-of-a-country-nurse-on-a-scottish-isle_885/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/burning_884/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/bossypants_883/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/bitch-planet-vol-1-extraordinary-machine-bitch-planet-collected-editions_882/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/avatar-the-last-airbender-smoke-and-shadow-part-3-smoke-and-shadow-3_881/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-7.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/a-world-of-flavor-your-gluten-free-passport_879/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/a-piece-of-sky-a-grain-of-rice-a-memoir-in-four-meditations_878/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/a-murder-in-time_877/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/a-flight-of-arrows-the-pathfinders-2_876/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/a-fierce-and-subtle-poison_875/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/a-court-of-thorns-and-roses-a-court-of-thorns-and-roses-1_874/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/unqualified-how-god-uses-broken-people-to-do-big-things_873/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/you-are-what-you-love-the-spiritual-power-of-habit_872/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/william-shakespeares-star-wars-verily-a-new-hope-william-shakespeares-star-wars-4_871/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/tuesday-nights-in-1980_870/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/tracing-numbers-on-a-train_869/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/throne-of-glass-throne-of-glass-1_868/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/thomas-jefferson-and-the-tripoli-pirates-the-forgotten-war-that-changed-american-history_867/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/thirteen-reasons-why_866/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-white-cat-and-the-monk-a-retelling-of-the-poem-pangur-ban_865/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-wedding-dress_864/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-vacationers_863/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-third-wave-an-entrepreneurs-vision-of-the-future_862/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-stranger_861/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-8.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-secret-the-secret-1_859/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-regional-office-is-under-attack_858/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-psychopath-test-a-journey-through-the-madness-industry_857/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-project_856/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-power-of-now-a-guide-to-spiritual-enlightenment_855/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-omnivores-dilemma-a-natural-history-of-four-meals_854/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-nerdy-nummies-cookbook-sweet-treats-for-the-geek-in-all-of-us_853/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-murder-of-roger-ackroyd-hercule-poirot-4_852/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-mistake-off-campus-2_851/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-matchmakers-playbook-wingmen-inc-1_850/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-love-and-lemons-cookbook-an-apple-to-zucchini-celebration-of-impromptu-cooking_849/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-long-shadow-of-small-ghosts-murder-and-memory-in-an-american-city_848/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-kite-runner_847/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-house-by-the-lake_846/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-glittering-court-the-glittering-court-1_845/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-girl-on-the-train_844/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-genius-of-birds_843/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-emerald-mystery_842/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-cookies-cups-cookbook-125-sweet-savory-recipes-reminding-you-to-always-eat-dessert-first_841/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-9.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-artists-way-a-spiritual-path-to-higher-creativity_839/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-art-of-war_838/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-argonauts_837/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-10-entrepreneur-live-your-startup-dream-without-quitting-your-day-job_836/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/suddenly-in-love-lake-haven-1_835/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/something-more-than-this_834/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/soft-apocalypse_833/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/so-youve-been-publicly-shamed_832/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/shoe-dog-a-memoir-by-the-creator-of-nike_831/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/shobu-samurai-project-aryoku-3_830/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/secrets-and-lace-fatal-hearts-1_829/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/scarlett-epstein-hates-it-here_828/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/romero-and-juliet-a-tragic-tale-of-love-and-zombies_827/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/redeeming-love_826/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/poses-for-artists-volume-1-dynamic-and-sitting-poses-an-essential-reference-for-figure-drawing-and-the-human-form_825/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/poems-that-make-grown-women-cry_824/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/nightingale-sing_823/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/night-sky-with-exit-wounds_822/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/mrs-houdini_821/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-10.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/modern-romance_820/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/miss-peregrines-home-for-peculiar-children-miss-peregrines-peculiar-children-1_819/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/louisa-the-extraordinary-life-of-mrs-adams_818/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/little-red_817/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/library-of-souls-miss-peregrines-peculiar-children-3_816/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/large-print-heart-of-the-pride_815/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/i-had-a-nice-time-and-other-lies-how-to-find-love-sht-like-that_814/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/hollow-city-miss-peregrines-peculiar-children-2_813/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/grumbles_812/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/frostbite-vampire-academy-2_810/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/follow-you-home_809/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/first-steps-for-new-christians-print-edition_808/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/finders-keepers-bill-hodges-trilogy-2_807/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/fables-vol-1-legends-in-exile-fables-1_806/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/eureka-trivia-60_805/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/drive-the-surprising-truth-about-what-motivates-us_804/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/done-rubbed-out-reightman-bailey-1_803/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/doing-it-over-most-likely-to-1_802/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/deliciously-ella-every-day-quick-and-easy-recipes-for-gluten-free-snacks-packed-lunches-and-simple-meals_801/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-11.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/dark-notes_800/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/daring-greatly-how-the-courage-to-be-vulnerable-transforms-the-way-we-live-love-parent-and-lead_799/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/close-to-you_798/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/chasing-heaven-what-dying-taught-me-about-living_797/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/big-magic-creative-living-beyond-fear_796/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/becoming-wise-an-inquiry-into-the-mystery-and-art-of-living_795/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/beauty-restored-riley-family-legacy-novellas-3_794/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/batman-the-long-halloween-batman_793/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/batman-the-dark-knight-returns-batman_792/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/ayumis-violin_791/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/anonymous_790/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/amy-meets-the-saints-and-sages_789/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/amid-the-chaos_788/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/amatus_787/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/agnostic-a-spirited-manifesto_786/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/zealot-the-life-and-times-of-jesus-of-nazareth_785/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/you-you-1_784/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/wonder-woman-earth-one-volume-one-wonder-woman-earth-one-1_783/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/wild-swans_782/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/why-the-right-went-wrong-conservatism-from-goldwater-to-the-tea-party-and-beyond_781/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-12.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/whats-it-like-in-space-stories-from-astronauts-whove-been-there_779/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/we-are-robin-vol-1-the-vigilante-business-we-are-robin-1_778/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/walt-disneys-alice-in-wonderland_777/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/v-for-vendetta-v-for-vendetta-complete_776/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/until-friday-night-the-field-party-1_775/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/unbroken-a-world-war-ii-story-of-survival-resilience-and-redemption_774/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/twenty-yawns_773/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/through-the-woods_772/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/this-is-where-it-ends_771/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-year-of-magical-thinking_770/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-wright-brothers_769/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-white-queen-the-cousins-war-1_768/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-wedding-pact-the-omalleys-2_767/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-time-keeper_766/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-testament-of-mary_765/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-star-touched-queen_764/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-songs-of-the-gods_763/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-song-of-achilles_762/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-rosie-project-don-tillman-1_761/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-13.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-power-of-habit-why-we-do-what-we-do-in-life-and-business_760/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-marriage-of-opposites_759/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-lucifer-effect-understanding-how-good-people-turn-evil_758/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-long-haul-diary-of-a-wimpy-kid-9_757/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-loney_756/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-literature-book-big-ideas-simply-explained_755/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-last-mile-amos-decker-2_754/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-immortal-life-of-henrietta-lacks_753/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-hidden-oracle-the-trials-of-apollo-1_752/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-help-yourself-cookbook-for-kids-60-easy-plant-based-recipes-kids-can-make-to-stay-healthy-and-save-the-earth_751/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-guilty-will-robie-4_750/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-first-hostage-jb-collins-2_749/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-dovekeepers_748/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-darkest-lie_747/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-bane-chronicles-the-bane-chronicles-1-11_746/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-bad-ass-librarians-of-timbuktu-and-their-race-to-save-the-worlds-most-precious-manuscripts_745/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-14th-colony-cotton-malone-11_744/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/that-darkness-gardiner-and-renner-1_743/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/tastes-like-fear-di-marnie-rome-3_742/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/take-me-with-you_741/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-14.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/swell-a-year-of-waves_740/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/superman-vol-1-before-truth-superman-by-gene-luen-yang-1_739/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/still-life-with-bread-crumbs_738/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/steve-jobs_737/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/sorting-the-beef-from-the-bull-the-science-of-food-fraud-forensics_736/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/someone-like-you-the-harrisons-2_735/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/so-cute-it-hurts-vol-6-so-cute-it-hurts-6_734/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/shtum_733/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/salt_731/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/robin-war_730/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/red-hoodarsenal-vol-1-open-for-business-red-hoodarsenal-1_729/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/rain-fish_728/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/quarter-life-poetry-poems-for-the-young-broke-and-hangry_727/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/pet-sematary_726/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/overload-how-to-unplug-unwind-and-unleash-yourself-from-the-pressure-of-stress_725/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/once-was-a-time_724/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/old-school-diary-of-a-wimpy-kid-10_723/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/no-dream-is-too-high-life-lessons-from-a-man-who-walked-on-the-moon_722/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/naruto-3-in-1-edition-vol-14-includes-vols-40-41-42-naruto-omnibus-14_721/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-15.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/my-name-is-lucy-barton_720/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/my-mrs-brown_719/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/my-kind-of-crazy_718/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/mr-mercedes-bill-hodges-trilogy-1_717/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/more-than-music-chasing-the-dream-1_716/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/made-to-stick-why-some-ideas-survive-and-others-die_715/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/luis-paints-the-world_714/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/luckiest-girl-alive_713/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/lowriders-to-the-center-of-the-earth-lowriders-in-space-2_712/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/love-is-a-mix-tape-music-1_711/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/looking-for-lovely-collecting-the-moments-that-matter_710/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/living-leadership-by-insight-a-good-leader-achieves-a-great-leader-builds-monuments_709/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/let-it-out-a-journey-through-journaling_708/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/lady-midnight-the-dark-artifices-1_707/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/its-all-easy-healthy-delicious-weeknight-meals-in-under-30-minutes_706/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/island-of-dragons-unwanteds-7_705/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/i-know-what-im-doing-and-other-lies-i-tell-myself-dispatches-from-a-life-under-construction_704/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/i-am-pilgrim-pilgrim-1_703/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/hyperbole-and-a-half-unfortunate-situations-flawed-coping-mechanisms-mayhem-and-other-things-that-happened_702/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/hush-hush-hush-hush-1_701/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-16.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/hold-your-breath-search-and-rescue-1_700/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/hamilton-the-revolution_699/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/greek-mythic-history_698/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/god-the-most-unpleasant-character-in-all-fiction_697/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/glory-over-everything-beyond-the-kitchen-house_696/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/feathers-displays-of-brilliant-plumage_695/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/far-away-places-on-the-brink-of-change-seven-continents-twenty-five-years_694/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/every-last-word_693/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/eligible-the-austen-project-4_692/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/el-deafo_691/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/eight-hundred-grapes_690/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/eaternity-more-than-150-deliciously-easy-vegan-recipes-for-a-long-healthy-satisfied-joyful-life_689/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/eat-fat-get-thin_688/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/dont-get-caught_687/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/doctor-sleep-the-shining-2_686/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/demigods-magicians-percy-and-annabeth-meet-the-kanes-percy-jackson-kane-chronicles-crossover-1-3_685/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/dear-mr-knightley_684/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/daily-fantasy-sports_683/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/crazy-love-overwhelmed-by-a-relentless-god_682/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/cometh-the-hour-the-clifton-chronicles-6_681/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-17.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/clockwork-angel-the-infernal-devices-1_679/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/city-of-glass-the-mortal-instruments-3_678/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/city-of-fallen-angels-the-mortal-instruments-4_677/index.html and found 0 new links and 7 table rows.
# ...
# Crawled: https://books.toscrape.com/catalogue/run-spot-run-the-ethics-of-keeping-pets_106/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/new-moon-twilight-2_105/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/life_104/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/kindle-paperwhite-users-guide_103/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/h-is-for-hawk_102/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/girl-online-on-tour-girl-online-2_101/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-46.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/fruits-basket-vol-2-fruits-basket-2_100/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/diary-of-a-minecraft-zombie-book-1-a-scare-of-a-dare-an-unofficial-minecraft-book_99/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/y-the-last-man-vol-1-unmanned-y-the-last-man-1_98/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/while-you-were-mine_97/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/where-lightning-strikes-bleeding-stars-3_96/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/when-im-gone_95/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/ways-of-seeing_94/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/vampire-knight-vol-1-vampire-knight-1_93/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/vampire-girl-vampire-girl-1_92/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/twenty-love-poems-and-a-song-of-despair_91/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/travels-with-charley-in-search-of-america_90/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/three-wishes-river-of-time-california-1_89/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/this-one-moment-pushing-limits-1_88/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-zombie-room_87/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-wicked-the-divine-vol-1-the-faust-act-the-wicked-the-divine_86/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-tumor_85/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-story-of-hong-gildong_84/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-silent-wife_83/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-silent-twin-detective-jennifer-knight-3_82/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-selfish-gene_81/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-47.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-secret-healer_80/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-sandman-vol-1-preludes-and-nocturnes-the-sandman-volumes-1_79/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-republic_78/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-odyssey_77/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-no-1-ladies-detective-agency-no-1-ladies-detective-agency-1_76/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-nicomachean-ethics_75/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-name-of-the-wind-the-kingkiller-chronicle-1_74/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-mirror-the-maze-the-wrath-and-the-dawn-15_73/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-little-prince_72/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-light-of-the-fireflies_71/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-last-girl-the-dominion-trilogy-1_70/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-iliad_69/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-hook-up-game-on-1_68/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-haters_67/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-girl-you-lost_66/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-girl-in-the-ice-dci-erika-foster-1_65/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-end-of-the-jesus-era-an-investigation-1_64/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-edge-of-reason-bridget-jones-2_63/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-complete-maus-maus-1-2_62/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-communist-manifesto_61/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-48.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-bhagavad-gita_60/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-bette-davis-club_59/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/the-art-of-not-breathing_58/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/taking-shots-assassins-1_57/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/starlark_56/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/skip-beat-vol-01-skip-beat-1_55/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/sister-sable-the-mad-queen-1_54/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/shatter-me-shatter-me-1_53/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/shameless_52/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/shadow-rites-jane-yellowrock-10_51/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/settling-the-score-the-summer-games-1_50/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/sense-and-sensibility_49/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/saga-volume-1-saga-collected-editions-1_48/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/rhythm-chord-malykhin_47/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/rat-queens-vol-1-sass-sorcery-rat-queens-collected-editions-1-5_46/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/paradise-lost-paradise-1_45/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/paper-girls-vol-1-paper-girls-1-5_44/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/ouran-high-school-host-club-vol-1-ouran-high-school-host-club-1_43/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/origins-alphas-05_42/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/one-second-seven-7_41/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-49.html and found 42 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/on-the-road-duluoz-legend_40/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/old-records-never-die-one-mans-quest-for-his-vinyl-and-his-past_39/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/off-sides-off-1_38/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/of-mice-and-men_37/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/myriad-prentor-1_36/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/my-perfect-mistake-over-the-top-1_35/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/ms-marvel-vol-1-no-normal-ms-marvel-2014-2015-1_34/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/meditations_33/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/matilda_32/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/lost-among-the-living_31/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/lord-of-the-flies_30/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/listen-to-me-fusion-1_29/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/kitchens-of-the-great-midwest_28/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/jane-eyre_27/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/imperfect-harmony_26/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/icing-aces-hockey-2_25/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/hawkeye-vol-1-my-life-as-a-weapon-hawkeye-1_24/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/having-the-barbarians-baby-ice-planet-barbarians-75_23/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/giant-days-vol-1-giant-days-1-4_22/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/fruits-basket-vol-1-fruits-basket-1_21/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/page-50.html and found 41 new links and 0 table rows.
# Crawled: https://books.toscrape.com/catalogue/frankenstein_20/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/forever-rockers-the-rocker-12_19/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/fighting-fate-fighting-6_18/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/emma_17/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/eat-pray-love_16/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/deep-under-walker-security-1_15/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/choosing-our-religion-the-spiritual-lives-of-americas-nones_14/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/charlie-and-the-chocolate-factory-charlie-bucket-1_13/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/charitys-cross-charles-towne-belles-4_12/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/bright-lines_11/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/bridget-joness-diary-bridget-jones-1_10/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/bounty-colorado-mountain-7_9/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/blood-defense-samantha-brinkman-1_8/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/bleach-vol-1-strawberry-and-the-soul-reapers-bleach-1_7/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/beyond-good-and-evil_6/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/alice-in-wonderland-alices-adventures-in-wonderland-1_5/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/ajin-demi-human-volume-1-ajin-demi-human-1_4/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/a-spys-devotion-the-regency-spies-of-london-1_3/index.html and found 0 new links and 7 table rows.
# Crawled: https://books.toscrape.com/catalogue/1st-to-die-womens-murder-club-1_2/index.html and found 0 new links and 7 table rows.
#                   UPC Product Type  Price (excl. tax)  Price (incl. tax)  Tax  \
# 0    a897fe39b1053632        Books              51.77              51.77  0.0
# 1    90fa61229261140a        Books              53.74              53.74  0.0
# 2    6957f44c3847a760        Books              50.10              50.10  0.0
# 3    e00eb4fd7b871a48        Books              47.82              47.82  0.0
# 4    4165285e1663650f        Books              54.23              54.23  0.0
# ..                ...          ...                ...                ...  ...
# 995  cd2a2a70dd5d176d        Books              55.53              55.53  0.0
# 996  bfd5e1701c862ac3        Books              57.06              57.06  0.0
# 997  19fec36a1dfb4c16        Books              16.97              16.97  0.0
# 998  f684a82adc49f011        Books              53.98              53.98  0.0
# 999  228ba5e7577e1d49        Books              26.08              26.08  0.0
#
#                 Availability  Number of reviews
# 0    In stock (22 available)                  0
# 1    In stock (20 available)                  0
# 2    In stock (20 available)                  0
# 3    In stock (20 available)                  0
# 4    In stock (20 available)                  0
# ..                       ...                ...
# 995   In stock (1 available)                  0
# 996   In stock (1 available)                  0
# 997   In stock (1 available)                  0
# 998   In stock (1 available)                  0
# 999   In stock (1 available)                  0
#
# [1000 rows x 7 columns]
# Crawled: https://books.toscrape.com/catalogue/1000-places-to-see-before-you-die_1/index.html and found 0 new links and 7 table rows.

# %%
df.head()
# Out:
#                 UPC Product Type  Price (excl. tax)  Price (incl. tax)  Tax  \
# 0  a897fe39b1053632        Books              51.77              51.77  0.0
# 1  90fa61229261140a        Books              53.74              53.74  0.0
# 2  6957f44c3847a760        Books              50.10              50.10  0.0
# 3  e00eb4fd7b871a48        Books              47.82              47.82  0.0
# 4  4165285e1663650f        Books              54.23              54.23  0.0
#
#               Availability  Number of reviews
# 0  In stock (22 available)                  0
# 1  In stock (20 available)                  0
# 2  In stock (20 available)                  0
# 3  In stock (20 available)                  0
# 4  In stock (20 available)                  0

# %%
df_mio.head()
# Out:
#                 UPC Product Type Price (excl. tax) Price (incl. tax)    Tax  \
# 0  a897fe39b1053632        Books            £51.77            £51.77  £0.00
# 1  90fa61229261140a        Books            £53.74            £53.74  £0.00
# 2  6957f44c3847a760        Books            £50.10            £50.10  £0.00
# 3  e00eb4fd7b871a48        Books            £47.82            £47.82  £0.00
# 4  4165285e1663650f        Books            £54.23            £54.23  £0.00
#
#   Availability Number of reviews                                  Title  \
# 0           22                 0                   A Light in the Attic
# 1           20                 0                     Tipping the Velvet
# 2           20                 0                             Soumission
# 3           20                 0                          Sharp Objects
# 4           20                 0  Sapiens: A Brief History of Humankind
#
#     Price  \
# 0  £51.77
# 1  £53.74
# 2  £50.10
# 3  £47.82
# 4  £54.23
#
#                                                                                        Link
# 0                 https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html
# 1                    https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html
# 2                            https://books.toscrape.com/catalogue/soumission_998/index.html
# 3                         https://books.toscrape.com/catalogue/sharp-objects_997/index.html
# 4  https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html

# %% [markdown]
# # Differenze tra i due codici di scraping
#
# ## 1. Struttura e navigazione tra le pagine
#
# ### Codice mio (Primo esempio)
# - **Approccio**: Usa un ciclo `while` per navigare tra le pagine numerate (come `page-1.html`, `page-2.html`).
# - **Crawl per pagina**: Ogni pagina viene visitata una volta, e i dati dei libri vengono estratti dalla pagina attuale.
# - **Controllo delle pagine**: Avanza alla pagina successiva finché esistono pagine disponibili, basandosi su un incremento numerico nel link (`page-1`, `page-2`, ecc.) e controllando se la pagina successiva esiste.
#
# ### Codice Rigel (Secondo esempio)
# - **Approccio**: Usa un **crawling ricorsivo** (algoritmo BFS — Breadth First Search), dove visita i link trovati in ogni pagina in modo **dinamico**.
# - **Crawl per link**: Esplora ogni link trovato nella pagina (se il link è valido e non è già stato visitato), e poi prosegue visitando il link successivo in modalità ricorsiva.
# - **Controllo delle pagine**: Non segue un numero fisso di pagine, ma continua a esplorare i link trovati fino a quando non si esauriscono i collegamenti validi.
#
# ---
#
# ## 2. Gestione dei dati
#
# ### Codice mio (Primo esempio)
# - **Raccolta dei dati**: I dati vengono raccolti in un **DataFrame di Pandas**, con una lista di dizionari che contiene le informazioni estratte da ogni libro.
# - **Dettagli del libro**: Vengono estratti il titolo, il prezzo e i dettagli extra da una tabella HTML specifica e aggiunti a un elenco `book_data`.
# - **Struttura dei dati**: Ogni libro è rappresentato da un dizionario che contiene informazioni come il titolo, il prezzo e altri dettagli (come la disponibilità).
#
# ### Codice Rigel (Secondo esempio)
# - **Raccolta dei dati**: I dati vengono salvati in una lista chiamata `data`. Ogni volta che vengono trovati dati pertinenti in una tabella (convertiti in dizionari dalla funzione `rows_to_dict`), vengono aggiunti alla lista `data`.
# - **Dettagli**: I dati vengono estratti dalle tabelle HTML che appaiono nelle pagine visitate, non solo dai libri, ma da tutti i dati tabulari presenti.
# - **Salvataggio dei dati**: I dati vengono infine salvati in formato JSON nel file `books.json`, oltre a essere mostrati in un DataFrame di Pandas.
#
# ---
#
# ## 3. Ottimizzazione e gestione dei link
#
# ### Codice mio (Primo esempio)
# - **URL assoluti**: Costruisce manualmente gli URL completi per ogni libro visitato, ma non gestisce esplicitamente i link relativi a meno che non siano trasformati in assoluti.
# - **Navigazione fra pagine**: Il crawler segue un percorso fisso attraverso le pagine numerate senza esplorare altri collegamenti interni.
#
# ### Codice Rigel (Secondo esempio)
# - **Gestione dei link**: Utilizza un set `ignored` per tenere traccia dei link già visitati, evitando di visitare più volte lo stesso URL. Questo è fatto in tempo costante grazie all'uso del set.
# - **Link relativi**: Quando trova link relativi, li trasforma in link assoluti utilizzando la URL base, il che gli permette di seguire anche i link che non sono completamente formati.
# - **Navigazione dinamica**: Esplora ogni link trovato nella pagina in modo dinamico, senza un limite prefissato sul numero di pagine.
#
# ---
#
# ## 4. Esperienza utente e gestione del traffico
#
# ### Codice mio (Primo esempio)
# - **Paginazione manuale**: Si naviga solo tra pagine numerate con un limite prefissato (ad esempio, fermandosi a 10 libri), utile per scenari in cui si desidera limitare il numero di pagine esplorate.
#
# ### Codice Rigel (Secondo esempio)
# - **Pausa tra richieste**: Aggiunge un ritardo tra le richieste (con `time.sleep(1)`) per evitare di sovraccaricare il server, un approccio utile per non causare blocchi o rallentamenti nei siti web.
# - **Crawl completo e ricorsivo**: Non ha un limite predeterminato sul numero di pagine o link esplorati, ma continua a seguire e raccogliere i link fino a che non ci sono più URL validi da visitare.
#
# ---
#
# ## 5. Sintesi delle differenze
#
# ### Codice mio (Primo esempio)
# - **Approccio semplice e lineare** per navigare tra le pagine numerate di un sito.
# - **Limitato** a un numero fisso di libri o pagine.
# - **Raccolta dei dati** in un DataFrame di Pandas.
#
# ### Codice Rigel (Secondo esempio)
# - **Crawling ricorsivo dinamico** che esplora ogni link trovato, senza limiti di pagine.
# - **Gestione avanzata dei link** con tracciamento degli URL già visitati.
# - **Raccolta dei dati** in formato JSON, con possibilità di estrarre anche altri tipi di tabelle oltre ai libri.
# - **Approccio più flessibile** e adatto a siti con architetture di navigazione più complesse.
#
# ---
#
# ## Quale scegliere?
#
# - Se il sito ha una **paginazione semplice** (con pagine numerate), **Codice mio** è più adatto.
# - Se vuoi esplorare un sito con una **struttura di link complessa** o desideri raccogliere informazioni da tutte le pagine collegate in un sito, **Codice Rigel** con il crawling ricorsivo è la scelta migliore.
